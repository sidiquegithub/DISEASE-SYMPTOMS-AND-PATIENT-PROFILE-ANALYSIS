# %% [markdown]
# 1) Identify the 5 diseases that occured the most
# 2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
path = "C:/Users/sidiq/OneDrive/Desktop/GIT HUB PROJECTS/DISEASE SYMPTOMS/DISEASE-SYMPTOMS-AND-PATIENT-PROFILE-ANALYSIS/DATA/Disease_symptom_and_patient_profile_dataset.csv"

# %%
data = pd.read_csv(path)

# %%
data
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
data.isnull().sum()
# Out:
# Disease                 0
# Fever                   0
# Cough                   0
# Fatigue                 0
# Difficulty Breathing    0
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Outcome Variable        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 49

# %%
data.drop_duplicates(inpla
                     ce=True)

# %%
data.shape
# Out:
# (300, 10)

# %%
data['Disease'].nunique()
# Out:
# 116

# %% [markdown]
# ###  Identify the 5 diseases that occured the most

# %%
top_diseases = data["Disease"].value_counts().head(5)

# %%
top_diseases
# Out:
# Asthma          16
# Osteoporosis    12
# Stroke          11
# Hypertension    10
# Migraine        10
# Name: Disease, dtype: int64

# %%
# Data frame for top 5 diseases
top_diseases = data[(data['Disease'] == "Asthma") |
                    (data['Disease'] == "Osteoporosis") |
                    (data['Disease'] == "Stroke") |
                    (data['Disease'] == "Hypertension") |
                    (data['Disease'] == "Migraine")]

# %%
top_diseases
# Out:
#           Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 3          Asthma   Yes   Yes      No                  Yes   25    Male
# 10         Asthma   Yes    No      No                  Yes   28    Male
# 20         Stroke   Yes   Yes     Yes                  Yes   29  Female
# 28       Migraine   Yes    No      No                   No   30  Female
# 29       Migraine    No   Yes     Yes                   No   30  Female
# 34         Asthma   Yes   Yes      No                  Yes   30  Female
# 36         Asthma   Yes   Yes     Yes                  Yes   30  Female
# 50         Asthma    No    No      No                  Yes   31    Male
# 51   Osteoporosis    No    No      No                  Yes   31    Male
# 53       Migraine   Yes    No      No                   No   31  Female
# 56         Asthma    No   Yes     Yes                  Yes   35  Female
# 57         Asthma   Yes   Yes     Yes                  Yes   35  Female
# ...

# %%
top_diseases.shape
# Out:
# (59, 10)

# %%
plt.figure(figsize=(5,4))

top_diseases['Age'].plot.density()

# Add a title and labels
plt.title('Density Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Density')

# Show the plot
plt.show()

# %% [markdown]
# - 30-40 age group patients being hospitalized more frequently for this particular disease
